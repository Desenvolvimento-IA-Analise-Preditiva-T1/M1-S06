# %% [markdown]
# # Semana 06 - Aula 01
#
#
# ## Funções e Módulos

# %%
# Importando o módulo que criamos
from estatistica import *

# %%
# Importando o módulo que criamos
from modulo_calc import *

# %%
nova_lista = [12, 5, 100, 999]

# %%
calcular_media([12, 5, 100, 999])

# %%
nova_lista[0]

# %%
calcular_maximo([12,36,9000])

# %%
# from modulo_calc import func_produto
# from modulo_calc import func_soma

from estatistica import *



# func_produto(6, 5)

# %%
# Testando a função 
def calcular_maximo(lista):
    
    maior = lista[0]
    
    for numero in lista:
        if numero > maior:
            maior = numero
            
    return maior

# %%
calcular_maximo([1,3,200,8000])

# %%
modulo_calc.func_produto(6, 5)
